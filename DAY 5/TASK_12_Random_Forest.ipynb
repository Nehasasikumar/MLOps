# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['target'] = iris.target

# %%
X = df.drop(['target'], axis='columns')
y = df.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = RandomForestClassifier()
model.fit(X_train, y_train)
default_score = model.score(X_test, y_test)
print(f"Score with default n_estimators (10): {default_score}")
# Out:
# Score with default n_estimators (10): 0.9666666666666667

# %%
best_score = 0
best_n_estimators = 0

for i in range(1, 101):
    model = RandomForestClassifier(n_estimators=i)
    model.fit(X_train, y_train)
    score = model.score(X_test, y_test)
    if score > best_score:
        best_score = score
        best_n_estimators = i

print(f"Best score: {best_score} with n_estimators: {best_n_estimators}")
# Out:
# Best score: 1.0 with n_estimators: 3
